# %%
import pandas as pd

# %% [markdown]
# Integer

# %%
x = 10
y = -3

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x
# Out:
# 10

# %% [markdown]
# Floating Point Number

# %%
a = 3.14
b = 10.0

# %%
print(type(a))
# Out:
# <class 'float'>

# %%
a
# Out:
# 3.14

# %% [markdown]
# String

# %%
name = "Alice"
city = 'Yerevan'

# %%
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# Boolean

# %%
is_active = True
is_complete = False

# %%
is_active
# Out:
# True

# %%
print(type(is_active))
# Out:
# <class 'bool'>

# %%
#Variables are used to build logic.
price = 100
quantity = 3

revenue = price * quantity
revenue
# Out:
# 300
